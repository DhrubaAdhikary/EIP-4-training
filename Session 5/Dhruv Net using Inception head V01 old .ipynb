# %%
import keras
from keras.layers.core import Layer
import keras.backend as K
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()

# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0              1  \
# image_path                            resized/1.jpg  resized/2.jpg
# gender_female                                     0              1
# gender_male                                       1              0
# imagequality_Average                              1              1
# imagequality_Bad                                  0              0
# imagequality_Good                                 0              0
# age_15-25                                         0              0
# age_25-35                                         0              0
# age_35-45                                         1              1
# age_45-55                                         0              0
# age_55+                                           0              0
# weight_normal-healthy                             1              0
# weight_over-weight                                0              1
# weight_slightly-overweight                        0              0
# weight_underweight                                0              0
# carryingbag_Daily/Office/Work Bag                 0              0
# carryingbag_Grocery/Home/Plastic Bag              1              0
# carryingbag_None                                  0              1
# footwear_CantSee                                  0              0
# footwear_Fancy                                    0              0
# footwear_Normal                                   1              1
# emotion_Angry/Serious                             0              1
# emotion_Happy                                     0              0
# emotion_Neutral                                   1              0
# emotion_Sad                                       0              0
# bodypose_Back                                     0              0
# bodypose_Front-Frontish                           1              1
# bodypose_Side                                     0              0
#
#                                                   2              3  \
# image_path                            resized/3.jpg  resized/4.jpg
# gender_female                                     0              0
# gender_male                                       1              1
# imagequality_Average                              0              0
# imagequality_Bad                                  0              0
# imagequality_Good                                 1              1
# age_15-25                                         0              0
# age_25-35                                         0              0
# age_35-45                                         0              0
# age_45-55                                         1              1
# age_55+                                           0              0
# weight_normal-healthy                             1              1
# weight_over-weight                                0              0
# weight_slightly-overweight                        0              0
# weight_underweight                                0              0
# carryingbag_Daily/Office/Work Bag                 0              1
# carryingbag_Grocery/Home/Plastic Bag              1              0
# carryingbag_None                                  0              0
# footwear_CantSee                                  1              0
# footwear_Fancy                                    0              0
# footwear_Normal                                   0              1
# emotion_Angry/Serious                             0              0
# emotion_Happy                                     0              0
# emotion_Neutral                                   1              1
# emotion_Sad                                       0              0
# bodypose_Back                                     0              0
# bodypose_Front-Frontish                           1              1
# bodypose_Side                                     0              0
#
#                                                   4
# image_path                            resized/5.jpg
# gender_female                                     1
# gender_male                                       0
# imagequality_Average                              0
# imagequality_Bad                                  0
# imagequality_Good                                 1
# age_15-25                                         0
# age_25-35                                         0
# age_35-45                                         1
# age_45-55                                         0
# age_55+                                           0
# weight_normal-healthy                             0
# weight_over-weight                                0
# weight_slightly-overweight                        1
# weight_underweight                                0
# carryingbag_Daily/Office/Work Bag                 0
# carryingbag_Grocery/Home/Plastic Bag              0
# carryingbag_None                                  1
# footwear_CantSee                                  1
# footwear_Fancy                                    0
# footwear_Normal                                   0
# emotion_Angry/Serious                             0
# emotion_Happy                                     0
# emotion_Neutral                                   1
# emotion_Sad                                       0
# bodypose_Back                                     0
# bodypose_Front-Frontish                           1
# bodypose_Side                                     0

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        images = images.astype('float32') / 255
        images_mean = np.mean(images, axis=0)
        images -= images_mean

        if self.augmentation is not None:
            images = self.augmentation.flow(images, shuffle=False).next()
        
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        
        return images, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):

  """
  p : the probability that random erasing is performed
  s_l, s_h : minimum / maximum proportion of erased area against input image
  r_1, r_2 : minimum / maximum aspect ratio of erased area
  v_l, v_h : minimum / maximum value for erased area
  pixel_level : pixel-level randomization for erased area
  """

  def eraser(input_img):
    img_h, img_w, img_c = input_img.shape
    p_1 = np.random.rand()

    if p_1 > p:
        return input_img

    while True:
        s = np.random.uniform(s_l, s_h) * img_h * img_w
        r = np.random.uniform(r_1, r_2)
        w = int(np.sqrt(s / r))
        h = int(np.sqrt(s * r))
        left = np.random.randint(0, img_w)
        top = np.random.randint(0, img_h)

        if left + w <= img_w and top + h <= img_h:
            break

    if pixel_level:
        c = np.random.uniform(v_l, v_h, (h, w, img_c))
    else:
        c = np.random.uniform(v_l, v_h)

    input_img[top:top + h, left:left + w, :] = c

    return input_img

  return eraser

# %%
aug = ImageDataGenerator(
# set input mean to 0 over the dataset
        
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        #Cutout Implementation
        preprocessing_function=get_random_eraser(p=0.1,v_l=0, v_h=0.5, s_l=0.008, s_h=0.05, pixel_level=False)
        # image data format, either "channels_first" or "channels_last"
       )

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32)
valid_gen = PersonDataGenerator(train_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'gender': 2,
#  'image_quality': 3,
#  'age': 5,
#  'weight': 4,
#  'bag': 3,
#  'pose': 3,
#  'footwear': 3,
#  'emotion': 4}

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D,  \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten
from keras.utils import plot_model
import cv2 
import numpy as np 
from keras.datasets import cifar10 
from keras import backend as K 
from keras.utils import np_utils

import math 
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(224, 224, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((5, 5), strides=3)(x)
x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(10, activation='softmax', name='auxilliary_output_1')(x1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


x2 = AveragePooling2D((5, 5), strides=3)(x)
x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
x2 = Flatten()(x2)
x2 = Dense(1024, activation='relu')(x2)
x2 = Dropout(0.7)(x2)
x2 = Dense(10, activation='softmax', name='auxilliary_output_2')(x2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

output = Dense(512, activation='softmax')(x)


backbone = Model(inputs=input_layer, outputs=output)
print(backbone.summary())

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# plot graph
plot_model(backbone, to_file='convolutional_neural_network.png')
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 56, 56, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d_1[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 192)  221376      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_7[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_13[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_20[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          524800      dropout_3[0][0]
# ==================================================================================================
# Total params: 6,498,352
# Trainable params: 6,498,352
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
neck = backbone.output

neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


Dhruv_net = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# plot graph
plot_model(backbone, to_file='convolutional_neural_network.png')

# %%
class CyclicLR(keras.callbacks.Callback):
    
    def __init__(self,base_lr, max_lr, step_size, base_m, max_m, cyclical_momentum):
 
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.base_m = base_m
        self.max_m = max_m
        self.cyclical_momentum = cyclical_momentum
        self.step_size = step_size
        
        self.clr_iterations = 0.
        self.cm_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}
        
    def clr(self):
        
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        
        if cycle == 2:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)          
            return self.base_lr-(self.base_lr-self.base_lr/100)*np.maximum(0,(1-x))
        
        else:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0,(1-x))
    
    def cm(self):
        
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        
        if cycle == 2:
            
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1) 
            return self.max_m
        
        else:
            x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
            return self.max_m - (self.max_m-self.base_m)*np.maximum(0,(1-x))
        
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())
            
        if self.cyclical_momentum == True:
            if self.clr_iterations == 0:
                K.set_value(self.model.optimizer.momentum, self.cm())
            else:
                K.set_value(self.model.optimizer.momentum, self.cm())
            
            
    def on_batch_begin(self, batch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)
        
        if self.cyclical_momentum == True:
            self.history.setdefault('momentum', []).append(K.get_value(self.model.optimizer.momentum))

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())
        
        if self.cyclical_momentum == True:
            K.set_value(self.model.optimizer.momentum, self.cm())

# %%
#define custom losses 


losses = {
"gender_output": "binary_crossentropy",
"image_quality_output": "categorical_crossentropy",
"age_output": "categorical_crossentropy",
"weight_output": "categorical_crossentropy",
"bag_output": "categorical_crossentropy",
"pose_output": "categorical_crossentropy",
"footwear_output": "categorical_crossentropy",
"emotion_output": "categorical_crossentropy"

}

# %%
opt = SGD(lr=0.001, momentum=0.9)
Dhruv_net.compile(
    optimizer=opt,
    loss=losses, 
    # loss_weights=loss_weights, 
    metrics=["accuracy"]
)

# %%
import sys
# the mock-0.3.1 dir contains testcase.py, testutils.py & mock.py
sys.path.append('D:/Assignment 6/keras_one_cycle_clr-master/keras_one_cycle_clr')

# %%
sys.path
# Out:
# ['c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\python36.zip',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\DLLs',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\lib',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36',
#  '',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\lib\\site-packages',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\win32',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\win32\\lib',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\Pythonwin',
#  'c:\\users\\ddr2kor\\appdata\\local\\programs\\python\\python36\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\ddr2kor\\.ipython',
#  'D:/Assignment 6/keras_one_cycle_clr-master/keras_one_cycle_clr']

# %%
from lr_range_test import LrRangeTest
from utils import *
from cyclic_lr import *
from one_cycle import *

# %%
batch_size=64

# %%
lrrf_cb = LrRangeTest(lr_range = (1e-6, 1),
                 wd_list = [5e-4],  # grid search for weight decay
                 steps=100,
                 batches_per_step=5,
                 threshold_multiplier=5.0,
                 validation_data=None,
                 batches_per_val = 5,
                 verbose=True)
n_epoch = 1
Dhruv_net.fit_generator(generator=train_gen, verbose=1,
          epochs=n_epoch,
          validation_data=None,
          callbacks=[lrrf_cb])
lrrf_cb.plot()

# %%
clr_cb = ktool.CLR(cyc=3,
                   lr_range=(1e-2/5, 1e-2),
                   momentum_range=(0.95, 0.85),
                   verbose=False,
                   amplitude_fn=lambda x: np.power(1.0/3, x))

clr_cb.test_run(600) # see that a new cycle starts at 0th, 200th, and 400th iteration.

# %%
clr_hist = Dhruv_net.fit(x_train, y_train,
                     epochs=60,
                     validation_data=(x_test, y_test),
                     verbose=2,
                     callbacks=[clr_cb])

plot_from_history(clr_hist)

# %%
epochs = 200
max_lr = 0.001
base_lr = max_lr/100
max_m = 0.98
base_m = 0.85

cyclical_momentum = True
augment = True
cycles = 8

iterations = round(len(train_df)/batch_size*epochs)
iterations = list(range(0,iterations+1))
step_size = len(iterations)/(cycles)


clr =  CyclicLR(base_lr=base_lr,
                max_lr=max_lr,
                step_size=step_size,
                max_m=max_m,
                base_m=base_m,
                cyclical_momentum=cyclical_momentum)

import os
from keras import backend as K
# Prepare model model saving directory.
save_dir = 'D:\Assignment 6\saved_models\\'
model_name = 'Dhruv_Net Inception Faster Convergence.h5' 
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)


# Prepare callbacks for model saving and for learning rate adjustment.
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath=filepath,
                             #monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

callbacks = [clr, checkpoint]
# Out:
# D:\Assignment 6\saved_models\Dhruv_Net Inception Faster Convergence.h5

# %%
# Run training, with or without data augmentation.
Dhruv_net.fit_generator(
          generator=train_gen,
          validation_data=valid_gen,

          epochs=200,

          #shuffle=True,
          callbacks=callbacks)
# Out:
# Epoch 1/200
# 360/360 [==============================] - 1245s 3s/step - loss: 9.1193 - gender_output_loss: 0.6908 - image_quality_output_loss: 1.0724 - age_output_loss: 1.5823 - weight_output_loss: 1.3071 - bag_output_loss: 1.0617 - footwear_output_loss: 1.0847 - pose_output_loss: 1.0512 - emotion_output_loss: 1.2690 - gender_output_accuracy: 0.5577 - image_quality_output_accuracy: 0.5102 - age_output_accuracy: 0.3807 - weight_output_accuracy: 0.5907 - bag_output_accuracy: 0.5240 - footwear_output_accuracy: 0.4282 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.6806 - val_loss: 8.5232 - val_gender_output_loss: 0.6874 - val_image_quality_output_loss: 1.0296 - val_age_output_loss: 1.5355 - val_weight_output_loss: 1.1752 - val_bag_output_loss: 1.0022 - val_footwear_output_loss: 1.0626 - val_pose_output_loss: 0.9830 - val_emotion_output_loss: 1.0764 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00001: val_loss improved from inf to 8.52317, saving model to D:\Assignment 6\saved_models\Dhruv_Net Inception Faster Convergence.h5
# Epoch 2/200
# 360/360 [==============================] - 1188s 3s/step - loss: 8.1693 - gender_output_loss: 0.6861 - image_quality_output_loss: 1.0021 - age_output_loss: 1.4901 - weight_output_loss: 1.0750 - bag_output_loss: 0.9591 - footwear_output_loss: 1.0489 - pose_output_loss: 0.9447 - emotion_output_loss: 0.9634 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5524 - age_output_accuracy: 0.3990 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5607 - footwear_output_accuracy: 0.4469 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7092 - val_loss: 7.9133 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9851 - val_age_output_loss: 1.4531 - val_weight_output_loss: 1.0131 - val_bag_output_loss: 0.9304 - val_footwear_output_loss: 1.0397 - val_pose_output_loss: 0.9272 - val_emotion_output_loss: 0.9138 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00002: val_loss improved from 8.52317 to 7.91330, saving model to D:\Assignment 6\saved_models\Dhruv_Net Inception Faster Convergence.h5
# Epoch 3/200
# 360/360 [==============================] - 1185s 3s/step - loss: 7.9168 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9832 - age_output_loss: 1.4428 - weight_output_loss: 1.0015 - bag_output_loss: 0.9254 - footwear_output_loss: 1.0390 - pose_output_loss: 0.9273 - emotion_output_loss: 0.9122 - gender_output_accuracy: 0.5627 - image_quality_output_accuracy: 0.5528 - age_output_accuracy: 0.3989 - weight_output_accuracy: 0.6334 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6178 - emotion_output_accuracy: 0.7091 - val_loss: 7.8932 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4338 - val_weight_output_loss: 0.9915 - val_bag_output_loss: 0.9212 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9118 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00003: val_loss improved from 7.91330 to 7.89316, saving model to D:\Assignment 6\saved_models\Dhruv_Net Inception Faster Convergence.h5
# Epoch 4/200
# 360/360 [==============================] - 1190s 3s/step - loss: 7.8889 - gender_output_loss: 0.6853 - image_quality_output_loss: 0.9822 - age_output_loss: 1.4322 - weight_output_loss: 0.9906 - bag_output_loss: 0.9220 - footwear_output_loss: 1.0380 - pose_output_loss: 0.9275 - emotion_output_loss: 0.9111 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5524 - age_output_accuracy: 0.3990 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6176 - emotion_output_accuracy: 0.7095 - val_loss: 7.9059 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4293 - val_weight_output_loss: 0.9882 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9115 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00004: val_loss did not improve from 7.89316
# Epoch 5/200
# 360/360 [==============================] - 1187s 3s/step - loss: 7.8862 - gender_output_loss: 0.6856 - image_quality_output_loss: 0.9820 - age_output_loss: 1.4294 - weight_output_loss: 0.9891 - bag_output_loss: 0.9218 - footwear_output_loss: 1.0392 - pose_output_loss: 0.9272 - emotion_output_loss: 0.9120 - gender_output_accuracy: 0.5625 - image_quality_output_accuracy: 0.5526 - age_output_accuracy: 0.3987 - weight_output_accuracy: 0.6338 - bag_output_accuracy: 0.5605 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7092 - val_loss: 7.9096 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4278 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9203 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9114 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00005: val_loss did not improve from 7.89316
# Epoch 6/200
# 360/360 [==============================] - 1179s 3s/step - loss: 7.8826 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9820 - age_output_loss: 1.4285 - weight_output_loss: 0.9891 - bag_output_loss: 0.9209 - footwear_output_loss: 1.0382 - pose_output_loss: 0.9273 - emotion_output_loss: 0.9112 - gender_output_accuracy: 0.5630 - image_quality_output_accuracy: 0.5525 - age_output_accuracy: 0.3985 - weight_output_accuracy: 0.6338 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4474 - pose_output_accuracy: 0.6176 - emotion_output_accuracy: 0.7093 - val_loss: 7.9141 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4274 - val_weight_output_loss: 0.9880 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9111 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00006: val_loss did not improve from 7.89316
# Epoch 7/200
# 360/360 [==============================] - 1190s 3s/step - loss: 7.8833 - gender_output_loss: 0.6854 - image_quality_output_loss: 0.9818 - age_output_loss: 1.4286 - weight_output_loss: 0.9888 - bag_output_loss: 0.9213 - footwear_output_loss: 1.0385 - pose_output_loss: 0.9273 - emotion_output_loss: 0.9116 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5529 - age_output_accuracy: 0.3990 - weight_output_accuracy: 0.6338 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4471 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7093 - val_loss: 7.9142 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9114 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
# Epoch 00007: val_loss did not improve from 7.89316
# Epoch 8/200
# 360/360 [==============================] - 1187s 3s/step - loss: 7.8823 - gender_output_loss: 0.6852 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4278 - weight_output_loss: 0.9888 - bag_output_loss: 0.9211 - footwear_output_loss: 1.0385 - pose_output_loss: 0.9274 - emotion_output_loss: 0.9112 - gender_output_accuracy: 0.5629 - image_quality_output_accuracy: 0.5524 - age_output_accuracy: 0.3987 - weight_output_accuracy: 0.6338 - bag_output_accuracy: 0.5611 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7095 - val_loss: 7.9155 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9820 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9111 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00008: val_loss did not improve from 7.89316
# Epoch 9/200
# 360/360 [==============================] - 1185s 3s/step - loss: 7.8824 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9824 - age_output_loss: 1.4275 - weight_output_loss: 0.9897 - bag_output_loss: 0.9207 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9269 - emotion_output_loss: 0.9113 - gender_output_accuracy: 0.5624 - image_quality_output_accuracy: 0.5524 - age_output_accuracy: 0.3990 - weight_output_accuracy: 0.6335 - bag_output_accuracy: 0.5605 - footwear_output_accuracy: 0.4475 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7093 - val_loss: 7.9180 - val_gender_output_loss: 0.6852 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9111 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00009: val_loss did not improve from 7.89316
# Epoch 10/200
# 360/360 [==============================] - 1183s 3s/step - loss: 7.8833 - gender_output_loss: 0.6854 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4276 - weight_output_loss: 0.9889 - bag_output_loss: 0.9212 - footwear_output_loss: 1.0381 - pose_output_loss: 0.9273 - emotion_output_loss: 0.9124 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3987 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4473 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7091 - val_loss: 7.9133 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00010: val_loss did not improve from 7.89316
# Epoch 11/200
# 360/360 [==============================] - 1177s 3s/step - loss: 7.8834 - gender_output_loss: 0.6856 - image_quality_output_loss: 0.9821 - age_output_loss: 1.4280 - weight_output_loss: 0.9894 - bag_output_loss: 0.9213 - footwear_output_loss: 1.0380 - pose_output_loss: 0.9274 - emotion_output_loss: 0.9117 - gender_output_accuracy: 0.5633 - image_quality_output_accuracy: 0.5524 - age_output_accuracy: 0.3988 - weight_output_accuracy: 0.6335 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7090 - val_loss: 7.9148 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9881 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0380 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9113 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00011: val_loss did not improve from 7.89316
# Epoch 12/200
# 360/360 [==============================] - 1181s 3s/step - loss: 7.8822 - gender_output_loss: 0.6853 - image_quality_output_loss: 0.9825 - age_output_loss: 1.4278 - weight_output_loss: 0.9884 - bag_output_loss: 0.9210 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9275 - emotion_output_loss: 0.9113 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5525 - age_output_accuracy: 0.3988 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4469 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7094 - val_loss: 7.9152 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00012: val_loss did not improve from 7.89316
# Epoch 13/200
# 360/360 [==============================] - 1180s 3s/step - loss: 7.8825 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9816 - age_output_loss: 1.4277 - weight_output_loss: 0.9888 - bag_output_loss: 0.9210 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9275 - emotion_output_loss: 0.9121 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5527 - age_output_accuracy: 0.3990 - weight_output_accuracy: 0.6335 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4469 - pose_output_accuracy: 0.6176 - emotion_output_accuracy: 0.7090 - val_loss: 7.9189 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9820 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9880 - val_bag_output_loss: 0.9205 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9266 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00013: val_loss did not improve from 7.89316
# Epoch 14/200
# 360/360 [==============================] - 1185s 3s/step - loss: 7.8824 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9817 - age_output_loss: 1.4283 - weight_output_loss: 0.9891 - bag_output_loss: 0.9208 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9270 - emotion_output_loss: 0.9116 - gender_output_accuracy: 0.5625 - image_quality_output_accuracy: 0.5526 - age_output_accuracy: 0.3986 - weight_output_accuracy: 0.6339 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4468 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7093 - val_loss: 7.9173 - val_gender_output_loss: 0.6855 - val_image_quality_output_loss: 0.9820 - val_age_output_loss: 1.4272 - val_weight_output_loss: 0.9882 - val_bag_output_loss: 0.9205 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9111 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
# Epoch 00014: val_loss did not improve from 7.89316
# Epoch 15/200
# 360/360 [==============================] - 1178s 3s/step - loss: 7.8836 - gender_output_loss: 0.6857 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4278 - weight_output_loss: 0.9891 - bag_output_loss: 0.9208 - footwear_output_loss: 1.0386 - pose_output_loss: 0.9272 - emotion_output_loss: 0.9121 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5527 - age_output_accuracy: 0.3988 - weight_output_accuracy: 0.6336 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4469 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7091 - val_loss: 7.9168 - val_gender_output_loss: 0.6852 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00015: val_loss did not improve from 7.89316
# Epoch 16/200
# 360/360 [==============================] - 1179s 3s/step - loss: 7.8835 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4282 - weight_output_loss: 0.9890 - bag_output_loss: 0.9209 - footwear_output_loss: 1.0382 - pose_output_loss: 0.9270 - emotion_output_loss: 0.9125 - gender_output_accuracy: 0.5626 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3988 - weight_output_accuracy: 0.6338 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4469 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7090 - val_loss: 7.9126 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9820 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00016: val_loss did not improve from 7.89316
# Epoch 17/200
# 360/360 [==============================] - 1178s 3s/step - loss: 7.8821 - gender_output_loss: 0.6854 - image_quality_output_loss: 0.9822 - age_output_loss: 1.4281 - weight_output_loss: 0.9890 - bag_output_loss: 0.9207 - footwear_output_loss: 1.0381 - pose_output_loss: 0.9272 - emotion_output_loss: 0.9114 - gender_output_accuracy: 0.5625 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3987 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5605 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7094 - val_loss: 7.9138 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9879 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00017: val_loss did not improve from 7.89316
# Epoch 18/200
# 360/360 [==============================] - 1177s 3s/step - loss: 7.8819 - gender_output_loss: 0.6854 - image_quality_output_loss: 0.9825 - age_output_loss: 1.4279 - weight_output_loss: 0.9887 - bag_output_loss: 0.9212 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9268 - emotion_output_loss: 0.9111 - gender_output_accuracy: 0.5629 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3985 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5607 - footwear_output_accuracy: 0.4471 - pose_output_accuracy: 0.6179 - emotion_output_accuracy: 0.7093 - val_loss: 7.9145 - val_gender_output_loss: 0.6852 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9880 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00018: val_loss did not improve from 7.89316
# Epoch 19/200
# 360/360 [==============================] - 1190s 3s/step - loss: 7.8814 - gender_output_loss: 0.6853 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4284 - weight_output_loss: 0.9886 - bag_output_loss: 0.9210 - footwear_output_loss: 1.0384 - pose_output_loss: 0.9267 - emotion_output_loss: 0.9108 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3988 - weight_output_accuracy: 0.6339 - bag_output_accuracy: 0.5608 - footwear_output_accuracy: 0.4471 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7096 - val_loss: 7.9204 - val_gender_output_loss: 0.6852 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9879 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00019: val_loss did not improve from 7.89316
# Epoch 20/200
# 360/360 [==============================] - 1175s 3s/step - loss: 7.8818 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4279 - weight_output_loss: 0.9887 - bag_output_loss: 0.9209 - footwear_output_loss: 1.0386 - pose_output_loss: 0.9267 - emotion_output_loss: 0.9113 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3990 - weight_output_accuracy: 0.6337 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4467 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7093 - val_loss: 7.9176 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4271 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9113 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00020: val_loss did not improve from 7.89316
# Epoch 21/200
# 360/360 [==============================] - 1186s 3s/step - loss: 7.8816 - gender_output_loss: 0.6855 - image_quality_output_loss: 0.9819 - age_output_loss: 1.4282 - weight_output_loss: 0.9884 - bag_output_loss: 0.9209 - footwear_output_loss: 1.0385 - pose_output_loss: 0.9272 - emotion_output_loss: 0.9110 - gender_output_accuracy: 0.5625 - image_quality_output_accuracy: 0.5526 - age_output_accuracy: 0.3986 - weight_output_accuracy: 0.6336 - bag_output_accuracy: 0.5606 - footwear_output_accuracy: 0.4470 - pose_output_accuracy: 0.6174 - emotion_output_accuracy: 0.7093 - val_loss: 7.9178 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9879 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
# Epoch 00021: val_loss did not improve from 7.89316
# Epoch 22/200
# 360/360 [==============================] - 1184s 3s/step - loss: 7.8821 - gender_output_loss: 0.6853 - image_quality_output_loss: 0.9823 - age_output_loss: 1.4283 - weight_output_loss: 0.9885 - bag_output_loss: 0.9210 - footwear_output_loss: 1.0385 - pose_output_loss: 0.9270 - emotion_output_loss: 0.9111 - gender_output_accuracy: 0.5629 - image_quality_output_accuracy: 0.5523 - age_output_accuracy: 0.3984 - weight_output_accuracy: 0.6339 - bag_output_accuracy: 0.5607 - footwear_output_accuracy: 0.4469 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7093 - val_loss: 7.9133 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0379 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9113 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00022: val_loss did not improve from 7.89316
# Epoch 23/200
# 360/360 [==============================] - 1222s 3s/step - loss: 7.8818 - gender_output_loss: 0.6854 - image_quality_output_loss: 0.9822 - age_output_loss: 1.4281 - weight_output_loss: 0.9882 - bag_output_loss: 0.9212 - footwear_output_loss: 1.0385 - pose_output_loss: 0.9275 - emotion_output_loss: 0.9107 - gender_output_accuracy: 0.5628 - image_quality_output_accuracy: 0.5527 - age_output_accuracy: 0.3986 - weight_output_accuracy: 0.6339 - bag_output_accuracy: 0.5610 - footwear_output_accuracy: 0.4467 - pose_output_accuracy: 0.6173 - emotion_output_accuracy: 0.7095 - val_loss: 7.9147 - val_gender_output_loss: 0.6853 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9112 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00023: val_loss did not improve from 7.89316
# Epoch 24/200
# 360/360 [==============================] - 1218s 3s/step - loss: 7.8803 - gender_output_loss: 0.6853 - image_quality_output_loss: 0.9820 - age_output_loss: 1.4278 - weight_output_loss: 0.9883 - bag_output_loss: 0.9206 - footwear_output_loss: 1.0382 - pose_output_loss: 0.9269 - emotion_output_loss: 0.9113 - gender_output_accuracy: 0.5627 - image_quality_output_accuracy: 0.5525 - age_output_accuracy: 0.3991 - weight_output_accuracy: 0.6339 - bag_output_accuracy: 0.5609 - footwear_output_accuracy: 0.4471 - pose_output_accuracy: 0.6175 - emotion_output_accuracy: 0.7094 - val_loss: 7.9160 - val_gender_output_loss: 0.6852 - val_image_quality_output_loss: 0.9819 - val_age_output_loss: 1.4270 - val_weight_output_loss: 0.9878 - val_bag_output_loss: 0.9204 - val_footwear_output_loss: 1.0378 - val_pose_output_loss: 0.9265 - val_emotion_output_loss: 0.9113 - val_gender_output_accuracy: 0.5628 - val_image_quality_output_accuracy: 0.5522 - val_age_output_accuracy: 0.3992 - val_weight_output_accuracy: 0.6339 - val_bag_output_accuracy: 0.5607 - val_footwear_output_accuracy: 0.4472 - val_pose_output_accuracy: 0.6176 - val_emotion_output_accuracy: 0.7090
#
# Epoch 00024: val_loss did not improve from 7.89316
# Epoch 25/200
# 277/360 [======================>.......] - ETA: 10:38 - loss: 7.8823 - gender_output_loss: 0.6862 - image_quality_output_loss: 0.9833 - age_output_loss: 1.4278 - weight_output_loss: 0.9845 - bag_output_loss: 0.9253 - footwear_output_loss: 1.0396 - pose_output_loss: 0.9248 - emotion_output_loss: 0.9107 - gender_output_accuracy: 0.5591 - image_quality_output_accuracy: 0.5508 - age_output_accuracy: 0.4002 - weight_output_accuracy: 0.6349 - bag_output_accuracy: 0.5592 - footwear_output_accuracy: 0.4436 - pose_output_accuracy: 0.6194 - emotion_output_accuracy: 0.7093
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b1536b86cd9a> in <module>
#       7
#       8           #shuffle=True,
# ----> 9           callbacks=callbacks)
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3738         value = math_ops.cast(value, tensor.dtype)
#    3739       converted_inputs.append(value)
# -> 3740     outputs = self._graph_fn(*converted_inputs)
#    3741
#    3742     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1079       TypeError: For invalid positional/keyword argument combinations.
#    1080     """
# -> 1081     return self._call_impl(args, kwargs)
#    1082
#    1083   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1119       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1120           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1121     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1122
#    1123   def _filtered_call(self, args, kwargs):
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1222     if executing_eagerly:
#    1223       flat_outputs = forward_function.call(
# -> 1224           ctx, args, cancellation_manager=cancellation_manager)
#    1225     else:
#    1226       gradient_name = self._delayed_rewrite_functions.register()
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     509               inputs=args,
#     510               attrs=("executor_type", executor_type, "config_proto", config),
# --> 511               ctx=ctx)
#     512         else:
#     513           outputs = execute.execute_with_cancellation(
#
# c:\users\ddr2kor\appdata\local\programs\python\python36\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
