# %%
import keras
from keras.layers.core import Layer
import keras.backend as K
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras.applications.inception_v3 import InceptionV3

from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age               weight               carryingbag  \
# 0    male      Average  35-45       normal-healthy  Grocery/Home/Plastic Bag
# 1  female      Average  35-45          over-weight                      None
# 2    male         Good  45-55       normal-healthy  Grocery/Home/Plastic Bag
# 3    male         Good  45-55       normal-healthy     Daily/Office/Work Bag
# 4  female         Good  35-45  slightly-overweight                      None
#
#   footwear        emotion        bodypose     image_path
# 0   Normal        Neutral  Front-Frontish  resized/1.jpg
# 1   Normal  Angry/Serious  Front-Frontish  resized/2.jpg
# 2  CantSee        Neutral  Front-Frontish  resized/3.jpg
# 3   Normal        Neutral  Front-Frontish  resized/4.jpg
# 4  CantSee        Neutral  Front-Frontish  resized/5.jpg

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0              1  \
# image_path                            resized/1.jpg  resized/2.jpg
# gender_female                                     0              1
# gender_male                                       1              0
# imagequality_Average                              1              1
# imagequality_Bad                                  0              0
# imagequality_Good                                 0              0
# age_15-25                                         0              0
# age_25-35                                         0              0
# age_35-45                                         1              1
# age_45-55                                         0              0
# age_55+                                           0              0
# weight_normal-healthy                             1              0
# weight_over-weight                                0              1
# weight_slightly-overweight                        0              0
# weight_underweight                                0              0
# carryingbag_Daily/Office/Work Bag                 0              0
# carryingbag_Grocery/Home/Plastic Bag              1              0
# carryingbag_None                                  0              1
# footwear_CantSee                                  0              0
# footwear_Fancy                                    0              0
# footwear_Normal                                   1              1
# emotion_Angry/Serious                             0              1
# emotion_Happy                                     0              0
# emotion_Neutral                                   1              0
# emotion_Sad                                       0              0
# bodypose_Back                                     0              0
# bodypose_Front-Frontish                           1              1
# bodypose_Side                                     0              0
#
#                                                   2              3  \
# image_path                            resized/3.jpg  resized/4.jpg
# gender_female                                     0              0
# gender_male                                       1              1
# imagequality_Average                              0              0
# imagequality_Bad                                  0              0
# imagequality_Good                                 1              1
# age_15-25                                         0              0
# age_25-35                                         0              0
# age_35-45                                         0              0
# age_45-55                                         1              1
# age_55+                                           0              0
# weight_normal-healthy                             1              1
# weight_over-weight                                0              0
# weight_slightly-overweight                        0              0
# weight_underweight                                0              0
# carryingbag_Daily/Office/Work Bag                 0              1
# carryingbag_Grocery/Home/Plastic Bag              1              0
# carryingbag_None                                  0              0
# footwear_CantSee                                  1              0
# footwear_Fancy                                    0              0
# footwear_Normal                                   0              1
# emotion_Angry/Serious                             0              0
# emotion_Happy                                     0              0
# emotion_Neutral                                   1              1
# emotion_Sad                                       0              0
# bodypose_Back                                     0              0
# bodypose_Front-Frontish                           1              1
# bodypose_Side                                     0              0
#
#                                                   4
# image_path                            resized/5.jpg
# gender_female                                     1
# gender_male                                       0
# imagequality_Average                              0
# imagequality_Bad                                  0
# imagequality_Good                                 1
# age_15-25                                         0
# age_25-35                                         0
# age_35-45                                         1
# age_45-55                                         0
# age_55+                                           0
# weight_normal-healthy                             0
# weight_over-weight                                0
# weight_slightly-overweight                        1
# weight_underweight                                0
# carryingbag_Daily/Office/Work Bag                 0
# carryingbag_Grocery/Home/Plastic Bag              0
# carryingbag_None                                  1
# footwear_CantSee                                  1
# footwear_Fancy                                    0
# footwear_Normal                                   0
# emotion_Angry/Serious                             0
# emotion_Happy                                     0
# emotion_Neutral                                   1
# emotion_Sad                                       0
# bodypose_Back                                     0
# bodypose_Front-Frontish                           1
# bodypose_Side                                     0

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        
        images = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        images = images.astype('float32') / 255
        images_mean = np.mean(images, axis=0)
        images -= images_mean

        if self.augmentation is not None:
            images = self.augmentation.flow(images, shuffle=False).next()
        
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        
        return images, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.2)
train_df.shape, val_df.shape
# Out:
# ((10858, 28), (2715, 28))

# %%
train_gen = PersonDataGenerator(train_df, batch_size=32)
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'gender': 2,
#  'image_quality': 3,
#  'age': 5,
#  'weight': 4,
#  'bag': 3,
#  'pose': 3,
#  'footwear': 3,
#  'emotion': 4}

# %%
# Convolutional Neural Network
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D,GlobalAveragePooling2D
sequential_Input = Input(shape=(224,224,3))

Sequential_NN1_1=Conv2D(32, kernel_size=3, activation='relu', use_bias=False)(sequential_Input)
Sequential_NN1_1_BN=BatchNormalization()(Sequential_NN1_1)
Sequential_NN1_1_DRP=Dropout(0.2)(Sequential_NN1_1_BN)
Sequential_NN1_2=Conv2D(64, kernel_size=3, activation='relu', use_bias=False)(Sequential_NN1_1_DRP)
Sequential_NN1_2_BN=BatchNormalization()(Sequential_NN1_2)
Sequential_NN1_2_DRP=Dropout(0.2)(Sequential_NN1_2_BN)
Sequential_NN1_3=Conv2D(32, kernel_size=1, activation='relu', use_bias=False)(Sequential_NN1_2_DRP)
Sequential_NN_pool1= MaxPooling2D()(Sequential_NN1_3)


Sequential_NN2_1=Conv2D(32, kernel_size=3, activation='relu', use_bias=False)(Sequential_NN_pool1)
Sequential_NN2_1_BN=BatchNormalization()(Sequential_NN2_1)
Sequential_NN2_1_DRP=Dropout(0.2)(Sequential_NN2_1_BN)
Sequential_NN2_2=Conv2D(64, kernel_size=3, activation='relu')(Sequential_NN2_1_DRP)
Sequential_NN2_2_BN=BatchNormalization()(Sequential_NN2_2)
Sequential_NN2_2_DRP=Dropout(0.2)(Sequential_NN2_2_BN)
Sequential_NN2_3=Conv2D(32, kernel_size=1, activation='relu', use_bias=False)(Sequential_NN2_2_DRP)
Sequential_NN_pool2= MaxPooling2D()(Sequential_NN2_3)



Sequential_NN3_1=Conv2D(32, kernel_size=3, activation='relu', use_bias=False)(Sequential_NN_pool2)
Sequential_NN3_1_BN=BatchNormalization()(Sequential_NN3_1)
Sequential_NN3_1_DRP=Dropout(0.1)(Sequential_NN3_1_BN)
Sequential_NN3_2=Conv2D(64, kernel_size=3, activation='relu')(Sequential_NN3_1_DRP)
Sequential_NN3_2_BN=BatchNormalization()(Sequential_NN3_2)
Sequential_NN3_2_DRP=Dropout(0.1)(Sequential_NN3_2_BN)
Sequential_NN3_3=Conv2D(32, kernel_size=1, activation='relu', use_bias=False)(Sequential_NN3_2_DRP)
Sequential_NN_pool3= MaxPooling2D()(Sequential_NN2_3)




Sequential_NN4_1=Conv2D(32, kernel_size=3, activation='relu', use_bias=False)(Sequential_NN_pool3)
Sequential_NN4_1_BN=BatchNormalization()(Sequential_NN4_1)
Sequential_NN4_1_DRP=Dropout(0.1)(Sequential_NN4_1_BN)
Sequential_NN4_2=Conv2D(64, kernel_size=3, activation='relu')(Sequential_NN4_1_DRP)
Sequential_NN4_2_BN=BatchNormalization()(Sequential_NN4_2)
Sequential_NN4_2_DRP=Dropout(0.1)(Sequential_NN4_2_BN)
Sequential_NN4_3=Conv2D(32, kernel_size=1, activation='relu', use_bias=False)(Sequential_NN4_2_DRP)
Sequential_NN_pool4= MaxPooling2D()(Sequential_NN4_3)


Sequential_NN_GAP=GlobalAveragePooling2D()(Sequential_NN_pool4)
Output=Dense(64, activation='softmax')(Sequential_NN_GAP)

backbone = Model(inputs=sequential_Input, outputs=Output)
print(backbone.summary())

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# plot graph
plot_model(backbone, to_file='convolutional_neural_network.png')
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 222, 222, 32)      864
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 222, 222, 32)      128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 222, 222, 32)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 220, 220, 64)      18432
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 220, 220, 64)      256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 220, 220, 64)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 220, 220, 32)      2048
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 108, 108, 32)      9216
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 108, 108, 32)      128
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 106, 106, 64)      18496
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 106, 106, 64)      256
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 106, 106, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 106, 106, 32)      2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 53, 53, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 51, 51, 32)        9216
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 51, 51, 32)        128
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 51, 51, 32)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 49, 49, 64)        18496
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 49, 49, 64)        256
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 49, 49, 32)        2048
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                2112
# =================================================================
# Total params: 84,128
# Trainable params: 83,552
# Non-trainable params: 576
# _________________________________________________________________
# None

# %%
neck = backbone.output
neck = Dense(64, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))

Dhruv_net = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

print(Dhruv_net.summary())

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
# plot graph
plot_model(Dhruv_net, to_file='convolutional_neural_network.png')
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 222, 222, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 222, 222, 32) 128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 222, 222, 32) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 220, 220, 64) 18432       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 220, 220, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 220, 220, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 220, 220, 32) 2048        dropout_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 110, 110, 32) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 108, 108, 32) 9216        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 108, 108, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 108, 108, 32) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 106, 106, 64) 18496       dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 106, 106, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 106, 106, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 106, 106, 32) 2048        dropout_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 53, 53, 32)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 51, 51, 32)   9216        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 51, 51, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 51, 51, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 49, 49, 64)   18496       dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 49, 49, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 49, 49, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 49, 49, 32)   2048        dropout_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 24, 24, 32)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 32)           0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           2112        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          8320        dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          8320        dropout_20[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          8320        dropout_22[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          8320        dropout_24[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          8320        dropout_26[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128)          8320        dropout_28[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 128)          8320        dropout_32[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          8320        dropout_30[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_5[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_7[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_9[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_11[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_13[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_15[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_19[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            516         dense_17[0][0]
# ==================================================================================================
# Total params: 158,331
# Trainable params: 157,755
# Non-trainable params: 576
# __________________________________________________________________________________________________
# None

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_type='Dhruv_Net v3'
model_name = 'customcnn_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(filepath=filepath,
                             #monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

# %%
losses = {
"gender_output": "binary_crossentropy",
"image_quality_output": "categorical_crossentropy",
"age_output": "categorical_crossentropy",
"weight_output": "categorical_crossentropy",
  "bag_output": "categorical_crossentropy",
  "pose_output": "categorical_crossentropy",
  "footwear_output": "categorical_crossentropy",
  "emotion_output": "categorical_crossentropy"

}

from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(lr * 1/(1 + 0.023 * epoch), 10)

loss_weights = {"gender_output": 0.89, "image_quality_output": 1.0, "age_output": 1.0, "weight_output": 0.9, "bag_output": 0.9 ,"pose_output": 1.0,
  "footwear_output": 0.9,
  "emotion_output": 1.0}
 #loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.0}
opt = optimizer=Adam(lr=0.2)

Dhruv_net.compile(
    optimizer=opt,
    loss=losses, 
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)

# %%
callbacks=[LearningRateScheduler(scheduler, verbose=1),checkpoint]

# %%
Dhruv_net.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    epochs=50,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.200000003.
# 339/339 [==============================] - 5536s 16s/step - loss: 7.8218 - gender_output_loss: 0.7197 - image_quality_output_loss: 1.0470 - age_output_loss: 1.4569 - weight_output_loss: 1.0218 - bag_output_loss: 0.9602 - footwear_output_loss: 1.0843 - pose_output_loss: 0.9691 - emotion_output_loss: 0.9487 - gender_output_accuracy: 0.5312 - image_quality_output_accuracy: 0.5452 - age_output_accuracy: 0.3937 - weight_output_accuracy: 0.6331 - bag_output_accuracy: 0.5558 - footwear_output_accuracy: 0.4183 - pose_output_accuracy: 0.6138 - emotion_output_accuracy: 0.7102 - val_loss: 7.7266 - val_gender_output_loss: 0.6894 - val_image_quality_output_loss: 0.9780 - val_age_output_loss: 1.4480 - val_weight_output_loss: 1.0067 - val_bag_output_loss: 0.9237 - val_footwear_output_loss: 1.0371 - val_pose_output_loss: 0.9374 - val_emotion_output_loss: 0.9249 - val_gender_output_accuracy: 0.5815 - val_image_quality_output_accuracy: 0.5632 - val_age_output_accuracy: 0.3917 - val_weight_output_accuracy: 0.6376 - val_bag_output_accuracy: 0.5737 - val_footwear_output_accuracy: 0.4535 - val_pose_output_accuracy: 0.6243 - val_emotion_output_accuracy: 0.7050
#
# Epoch 00001: val_loss improved from inf to 7.72656, saving model to D:\Assignment 6\saved_models\customcnn_Dhruv_Net v3_model.001.h5
# Epoch 2/50
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.1955034242.
# 339/339 [==============================] - 7234s 21s/step - loss: 7.5657 - gender_output_loss: 0.6922 - image_quality_output_loss: 0.9976 - age_output_loss: 1.4361 - weight_output_loss: 0.9895 - bag_output_loss: 0.9266 - footwear_output_loss: 1.0497 - pose_output_loss: 0.9367 - emotion_output_loss: 0.9101 - gender_output_accuracy: 0.5409 - image_quality_output_accuracy: 0.5497 - age_output_accuracy: 0.3956 - weight_output_accuracy: 0.6351 - bag_output_accuracy: 0.5587 - footwear_output_accuracy: 0.4285 - pose_output_accuracy: 0.6162 - emotion_output_accuracy: 0.7135 - val_loss: 7.7781 - val_gender_output_loss: 0.6986 - val_image_quality_output_loss: 0.9739 - val_age_output_loss: 1.4545 - val_weight_output_loss: 0.9972 - val_bag_output_loss: 0.9219 - val_footwear_output_loss: 1.0579 - val_pose_output_loss: 0.9205 - val_emotion_output_loss: 0.9259 - val_gender_output_accuracy: 0.4185 - val_image_quality_output_accuracy: 0.5632 - val_age_output_accuracy: 0.3917 - val_weight_output_accuracy: 0.6376 - val_bag_output_accuracy: 0.5737 - val_footwear_output_accuracy: 0.4535 - val_pose_output_accuracy: 0.6243 - val_emotion_output_accuracy: 0.7050
#
# Epoch 00002: val_loss did not improve from 7.72656
# Epoch 3/50
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.1869057635.
# 339/339 [==============================] - 7448s 22s/step - loss: 7.5689 - gender_output_loss: 0.6928 - image_quality_output_loss: 0.9920 - age_output_loss: 1.4383 - weight_output_loss: 0.9914 - bag_output_loss: 0.9260 - footwear_output_loss: 1.0503 - pose_output_loss: 0.9402 - emotion_output_loss: 0.9109 - gender_output_accuracy: 0.5391 - image_quality_output_accuracy: 0.5509 - age_output_accuracy: 0.3956 - weight_output_accuracy: 0.6352 - bag_output_accuracy: 0.5592 - footwear_output_accuracy: 0.4272 - pose_output_accuracy: 0.6162 - emotion_output_accuracy: 0.7135 - val_loss: 7.7735 - val_gender_output_loss: 0.6942 - val_image_quality_output_loss: 0.9832 - val_age_output_loss: 1.4614 - val_weight_output_loss: 0.9846 - val_bag_output_loss: 0.9190 - val_footwear_output_loss: 1.0482 - val_pose_output_loss: 0.9186 - val_emotion_output_loss: 0.9287 - val_gender_output_accuracy: 0.4185 - val_image_quality_output_accuracy: 0.5632 - val_age_output_accuracy: 0.3917 - val_weight_output_accuracy: 0.6376 - val_bag_output_accuracy: 0.5737 - val_footwear_output_accuracy: 0.4535 - val_pose_output_accuracy: 0.6243 - val_emotion_output_accuracy: 0.7050
#
# Epoch 00003: val_loss did not improve from 7.72656
# Epoch 4/50
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.1748416806.
# 339/339 [==============================] - 7477s 22s/step - loss: 7.5575 - gender_output_loss: 0.6934 - image_quality_output_loss: 0.9908 - age_output_loss: 1.4360 - weight_output_loss: 0.9893 - bag_output_loss: 0.9252 - footwear_output_loss: 1.0499 - pose_output_loss: 0.9348 - emotion_output_loss: 0.9107 - gender_output_accuracy: 0.5365 - image_quality_output_accuracy: 0.5509 - age_output_accuracy: 0.3982 - weight_output_accuracy: 0.6354 - bag_output_accuracy: 0.5581 - footwear_output_accuracy: 0.4287 - pose_output_accuracy: 0.6163 - emotion_output_accuracy: 0.7135 - val_loss: 7.7677 - val_gender_output_loss: 0.6829 - val_image_quality_output_loss: 0.9789 - val_age_output_loss: 1.4437 - val_weight_output_loss: 0.9898 - val_bag_output_loss: 0.9380 - val_footwear_output_loss: 1.0360 - val_pose_output_loss: 0.9181 - val_emotion_output_loss: 0.9378 - val_gender_output_accuracy: 0.5815 - val_image_quality_output_accuracy: 0.5632 - val_age_output_accuracy: 0.3917 - val_weight_output_accuracy: 0.6376 - val_bag_output_accuracy: 0.5737 - val_footwear_output_accuracy: 0.4535 - val_pose_output_accuracy: 0.6243 - val_emotion_output_accuracy: 0.7050
#
# Epoch 00004: val_loss did not improve from 7.72656
# Epoch 5/50
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.1601114351.
# 186/339 [===============>..............] - ETA: 1:22:11 - loss: 7.5639 - gender_output_loss: 0.6932 - image_quality_output_loss: 1.0034 - age_output_loss: 1.4258 - weight_output_loss: 0.9878 - bag_output_loss: 0.9232 - footwear_output_loss: 1.0520 - pose_output_loss: 0.9385 - emotion_output_loss: 0.9126 - gender_output_accuracy: 0.5397 - image_quality_output_accuracy: 0.5415 - age_output_accuracy: 0.4052 - weight_output_accuracy: 0.6374 - bag_output_accuracy: 0.5588 - footwear_output_accuracy: 0.4244 - pose_output_accuracy: 0.6179 - emotion_output_accuracy: 0.7135
